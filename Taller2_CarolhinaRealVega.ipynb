# %% [markdown]
# Taller #2

# %% [markdown]
# Parte # 1

# %% [markdown]
# ejercicio 1.1:

# %%
def saludar(nombre):
    return f"Hola, {nombre}, bienvenid@ al curso de Python!"
pass

saludar("Caro")
# Out:
# 'Hola, Caro, bienvenid@ al curso de Python!'

# %% [markdown]
# ejercicio 1.2:

# %%
def calcular_area_rectangulo(base, altura):
    return f"el area es:{base * altura}"
pass

calcular_area_rectangulo(5,3)
# Out:
# 'el area es:15'

# %% [markdown]
# Ejercicio 1.3:

# %%
def calcular_promedio(nota1,nota2,nota3)
